# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/DELLL/Downloads/ecommerce_customer_behavior.csv")
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  Purchase Amount  \
# 0               1   63  Female        T-Shirt     Clothing             2026
# 1               2   51    Male       Sneakers     Footwear             4484
# 2               3   21  Female         Wallet  Accessories              812
# 3               4   61    Male          Watch  Accessories              395
# 4               5   60    Male          Boots     Footwear             1421
# ...           ...  ...     ...            ...          ...              ...
# 3995         3996   52  Female   Formal Shoes     Footwear             2676
# 3996         3997   35    Male   Sports Shoes     Footwear             3172
# 3997         3998   25    Male        Sandals     Footwear             1987
# 3998         3999   30  Female          Scarf  Accessories             3801
# 3999         4000   54  Female        Loafers     Footwear               70
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             4000 non-null   int64
#  1   Age                     4000 non-null   int64
#  2   Gender                  4000 non-null   str
#  3   Item Purchased          4000 non-null   str
#  4   Category                4000 non-null   str
#  5   Purchase Amount         4000 non-null   int64
#  6   Location                4000 non-null   str
#  7   Size                    4000 non-null   str
#  8   Color                   4000 non-null   str
#  9   Season                  4000 non-null   str
#  10  Review Rating           4000 non-null   float64
#  11  Subscription Status     4000 non-null   str
#  12  Shipping Type           4000 non-null   str
#  13  Discount Applied        4000 non-null   str
#  14  Promo Code              4000 non-null   str
# ...

# %%
df.describe(include='all')
# Out:
#         Customer ID          Age  Gender Item Purchased Category  \
# count   4000.000000  4000.000000    4000           4000     4000
# unique          NaN          NaN       2             33        4
# top             NaN          NaN  Female    Windcheater  Outwear
# freq            NaN          NaN    2012            156     1025
# mean    2000.500000    42.821250     NaN            NaN      NaN
# std     1154.844867    15.916081     NaN            NaN      NaN
# min        1.000000    16.000000     NaN            NaN      NaN
# 25%     1000.750000    29.000000     NaN            NaN      NaN
# 50%     2000.500000    42.000000     NaN            NaN      NaN
# 75%     3000.250000    57.000000     NaN            NaN      NaN
# max     4000.000000    70.000000     NaN            NaN      NaN
#
#         Purchase Amount Location  Size  Color  Season  Review Rating  \
# count       4000.000000     4000  4000   4000    4000    4000.000000
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount           0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code                0
# Previous Purchases        0
# Payment Mode              0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code ', 'Previous Purchases', 'Payment Mode',
#        'Frequency of Purchases'],
#       dtype='str')

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_', 'previous_purchases', 'payment_mode',
#        'frequency_of_purchases'],
#       dtype='str')

# %%
df= df.rename(columns={'promo_code_':'promo_code'})
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code', 'previous_purchases', 'payment_mode',
#        'frequency_of_purchases'],
#       dtype='str')

# %%
# create a column age_group
labels = ['young_adult', 'adult', 'middle_aged', 'senior']
df['age_group']=pd.qcut(df['age'], q=4, labels=labels)

# %%
df[['age','age_group']].head(30)
# Out:
#     age    age_group
# 0    63       senior
# 1    51  middle_aged
# 2    21  young_adult
# 3    61       senior
# 4    60       senior
# 5    29  young_adult
# 6    48  middle_aged
# 7    59       senior
# 8    39        adult
# 9    62       senior
# 10   57  middle_aged
# 11   18  young_adult
# 12   22  young_adult
# 13   24  young_adult
# 14   46  middle_aged
# 15   29  young_adult
# 16   20  young_adult
# 17   24  young_adult
# 18   34        adult
# 19   34        adult
# 20   26  young_adult
# 21   35        adult
# 22   27  young_adult
# 23   17  young_adult
# 24   22  young_adult
# 25   58       senior
# 26   41        adult
# 27   68       senior
# 28   31        adult
# 29   55  middle_aged

# %%
#create column purchase frequency days
frequency_mapping = {
    'Fortnightly':14,
    'Weekly':7,
    'Monthly':30,
    'Quarterly':90,
    'Annually':365}

# %%
df['purchase_frequency_days']= df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(10)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                        7                 Weekly
# 1                        7                 Weekly
# 2                       30                Monthly
# 3                      365               Annually
# 4                       90              Quarterly
# 5                      365               Annually
# 6                       30                Monthly
# 7                      365               Annually
# 8                       30                Monthly
# 9                      365               Annually

# %%
df
# Out:
#       customer_id  age  gender item_purchased     category  purchase_amount  \
# 0               1   63  Female        T-Shirt     Clothing             2026
# 1               2   51    Male       Sneakers     Footwear             4484
# 2               3   21  Female         Wallet  Accessories              812
# 3               4   61    Male          Watch  Accessories              395
# 4               5   60    Male          Boots     Footwear             1421
# ...           ...  ...     ...            ...          ...              ...
# 3995         3996   52  Female   Formal Shoes     Footwear             2676
# 3996         3997   35    Male   Sports Shoes     Footwear             3172
# 3997         3998   25    Male        Sandals     Footwear             1987
# 3998         3999   30  Female          Scarf  Accessories             3801
# 3999         4000   54  Female        Loafers     Footwear               70
#
# ...

# %%
df=df.drop('promo_code',axis=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_mode',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_days'],
#       dtype='str')

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 578.7 kB/s eta 0:00:04
#    --------------- ------------------------ 1.0/2.8 MB 898.8 kB/s eta 0:00:02
#    ------------------- -------------------- 1.3/2.8 MB 1.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.6/2.8 MB 1.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.6/2.8 MB 1.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.6/2.8 MB 1.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 2.4/2.8 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 1.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 4.2 MB/s eta 0:00:01
# ...

# %%
pip install pymysql sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: C:\Users\DELLL\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# MySQL connection details
username = "root"
password = quote_plus("Prakash@2478")   # Encodes special characters
host = "127.0.0.1"
port = "3306"
database = "first_pr_1"

# Create engine
engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
)

# Write DataFrame to MySQL
table_name = "mytable"
df.to_sql(table_name, con=engine, if_exists="replace", index=False)

# Read data back
result = pd.read_sql("SELECT * FROM mytable LIMIT 5;", con=engine)
print(result)
# Out:
#    customer_id  age  gender item_purchased     category  purchase_amount  \
# 0            1   63  Female        T-Shirt     Clothing             2026
# 1            2   51    Male       Sneakers     Footwear             4484
# 2            3   21  Female         Wallet  Accessories              812
# 3            4   61    Male          Watch  Accessories              395
# 4            5   60    Male          Boots     Footwear             1421
#
#     location size   color  season  review_rating subscription_status  \
# 0  Ahmedabad    M  Maroon  Summer            3.7                 Yes
# 1     Bhopal    M    Pink  Spring            4.2                 Yes
# 2     Nagpur    L    Navy  Spring            4.2                  No
# 3  Ahmedabad    L    Blue  Winter            4.5                  No
# 4      Patna    M   Black  Autumn            2.5                 Yes
#
#    shipping_type discount_applied  previous_purchases payment_mode  \
# ...

# %%
df.head(40)
# Out:
#     customer_id  age  gender item_purchased     category  purchase_amount  \
# 0             1   63  Female        T-Shirt     Clothing             2026
# 1             2   51    Male       Sneakers     Footwear             4484
# 2             3   21  Female         Wallet  Accessories              812
# 3             4   61    Male          Watch  Accessories              395
# 4             5   60    Male          Boots     Footwear             1421
# 5             6   29  Female         Wallet  Accessories             1761
# 6             7   48  Female   Formal Shoes     Footwear              764
# 7             8   59    Male        Handbag  Accessories             4418
# 8             9   39    Male   Formal Shoes     Footwear             4438
# 9            10   62  Female          Jeans     Clothing              586
# 10           11   57  Female        Sweater      Outwear             3608
# 11           12   18  Female        Sandals     Footwear              600
# ...
